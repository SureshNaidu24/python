# %% [markdown]
# <a href="https://colab.research.google.com/github/SureshNaid/python/blob/main/Day_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
k=[4,2,9,87.9999,40]

# %%
k
# Out:
# [4, 2, 9, 87.9999, 40]

# %%
pd.Series(k)
# Out:
# 0     4.0000
# 1     2.0000
# 2     9.0000
# 3    87.9999
# 4    40.0000
# dtype: float64

# %%
a=np.random.randint(20,50,15)
a
# Out:
# array([21, 44, 38, 32, 23, 30, 31, 34, 42, 20, 34, 28, 39, 40, 33])

# %%
a.ndim
# Out:
# 1

# %%
s=pd.Series(a)
s
# Out:
# 0     21
# 1     44
# 2     38
# 3     32
# 4     23
# 5     30
# 6     31
# 7     34
# 8     42
# 9     20
# 10    34
# 11    28
# 12    39
# 13    40
# 14    33
# dtype: int64

# %%
s[0]
# Out:
# 21

# %%
s[4:10]
# Out:
# 4    23
# 5    30
# 6    31
# 7    34
# 8    42
# 9    20
# dtype: int64

# %%
np.random.seed(34)
b=np.random.randint(100,200,(6,5))
b
# Out:
# array([[133, 185, 168, 135, 169],
#        [111, 178, 129, 118, 129],
#        [189, 129, 120, 196, 162],
#        [105, 120, 151, 119, 185],
#        [121, 163, 172, 142, 184],
#        [172, 177, 136, 102, 137]])

# %%
b.ndim
# Out:
# 2

# %%
df=pd.DataFrame(b,columns=['Roll','Name','age','adds','country'])
df
# Out:
#    Roll  Name  age  adds  country
# 0   133   185  168   135      169
# 1   111   178  129   118      129
# 2   189   129  120   196      162
# 3   105   120  151   119      185
# 4   121   163  172   142      184
# 5   172   177  136   102      137

# %%
df.iloc[0,0]
# Out:
# 133

# %%
df.loc[0,['Roll','Name','age']]
# Out:
# Roll    133
# Name    185
# age     168
# Name: 0, dtype: int64

# %%
df.iloc[[0,5]]
# Out:
#    Roll  Name  age  adds  country
# 0   133   185  168   135      169
# 5   172   177  136   102      137

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('diamonds')
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]
